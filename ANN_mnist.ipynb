# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
import numpy as np

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[550])

# %%
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

# %%
input_shape = (28, 28, 1)

# %%
model = Sequential()
model.add(Dense(64, input_shape= input_shape, activation='relu'))
model.add(Dense(32, activation='relu'))
#model.add(Dense(32, activation='relu'))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'], )

# %%
history = model.fit(x_train, y_train, epochs=20, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8584 - loss: 0.8016 - val_accuracy: 0.9072 - val_loss: 0.3202
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9113 - loss: 0.3230 - val_accuracy: 0.9115 - val_loss: 0.3176
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9169 - loss: 0.3009 - val_accuracy: 0.9234 - val_loss: 0.2914
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9219 - loss: 0.2878 - val_accuracy: 0.9239 - val_loss: 0.2806
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9216 - loss: 0.2879 - val_accuracy: 0.9207 - val_loss: 0.2809
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9230 - loss: 0.2842 - val_accuracy: 0.9181 - val_loss: 0.3048
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9266 - loss: 0.2631 - val_accuracy: 0.9195 - val_loss: 0.3483
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9277 - loss: 0.2713 - val_accuracy: 0.9288 - val_loss: 0.2683
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9284 - loss: 0.2572 - val_accuracy: 0.9279 - val_loss: 0.2918
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9302 - loss: 0.2538 - val_accuracy: 0.9178 - val_loss: 0.4139
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9324 - loss: 0.2460 - val_accuracy: 0.9208 - val_loss: 0.2936
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9311 - loss: 0.2484 - val_accuracy: 0.9267 - val_loss: 0.3168
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9357 - loss: 0.2340 - val_accuracy: 0.9254 - val_loss: 0.2687
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9348 - loss: 0.2286 - val_accuracy: 0.9282 - val_loss: 0.2531
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9342 - loss: 0.2288 - val_accuracy: 0.9208 - val_loss: 0.2707
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9361 - loss: 0.2281 - val_accuracy: 0.9314 - val_loss: 0.2709
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9400 - loss: 0.2158 - val_accuracy: 0.9334 - val_loss: 0.2824
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9407 - loss: 0.2085 - val_accuracy: 0.9240 - val_loss: 0.3296
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9436 - loss: 0.1991 - val_accuracy: 0.9302 - val_loss: 0.2764
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9472 - loss: 0.1883 - val_accuracy: 0.9250 - val_loss: 0.2976

# %%
from matplotlib import pyplot

pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()

pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
